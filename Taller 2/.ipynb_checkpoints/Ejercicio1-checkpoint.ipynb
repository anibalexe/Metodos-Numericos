# %%
using Plots
function graficar()
    raices = [-0.4, 2.2, 4.7]
    f(x)= -12-(21*x)+(18*x^2)-(2.75*x^3)
    Plots.scatter(f)
    plot([f,zero], -4, 6)
    scatter!(raices,[0,0,0])
end

graficar()
