# %%
function biseccion()
    a = 0.0
    b = 2.0
    c = 0.0
    evaluacionA = 0.0
    evaluacionB = 0.0
    evaluacionC = 0.0
    errorRelativoAprox = 1.0
    cont = 1
    
    #El ciclo se repite hasta que error es menor al 0.05%
    while errorRelativoAprox >= 0.05
        c = (a + b)/2
        evaluacionA = (a^4)-1-(3*exp(-a))
        evaluacionB = (b^4)-1-(3*exp(-b))
        evaluacionC = (c^4)-1-(3*exp(-c))
        println("Iteracion ",cont)
        println("a es: ",a,", b es: ",b,", c es: ",c,"\nf(a): ",evaluacionA,", f(b): ",evaluacionB,", f(c): ",evaluacionC)
        #Comprueba que valor se reemplazará por la variable c
        if evaluacionA*evaluacionC > 0
            #Calcula el error relativo aproximado porcentual
            errorRelativoAprox = abs((c-a)/c)*100
            a = c
            println("Actualizacion: a = c")
            
        else
            #Calcula el error relativo aproximado porcentual
            errorRelativoAprox = abs((c-b)/c)*100
            b = c
            println("Actualizacion: b = c")

        end
        println("Error relativo aproximado: ",errorRelativoAprox,"%\n")
        cont += 1
        
    end

end

biseccion()
# Out:
# Iteracion 1
# a es: 0.0, b es: 2.0, c es: 1.0
# f(a): -4.0, f(b): 14.593994150290161, f(c): -1.103638323514327
# Actualizacion: a = c
# Error relativo aproximado: 100.0%
#
# Iteracion 2
# a es: 1.0, b es: 2.0, c es: 1.5
# f(a): -1.103638323514327, f(b): 14.593994150290161, f(c): 3.3931095195547103
# Actualizacion: b = c
# Error relativo aproximado: 33.33333333333333%
#
# Iteracion 3
# a es: 1.0, b es: 1.5, c es: 1.25
# f(a): -1.103638323514327, f(b): 3.3931095195547103, f(c): 0.5818918594194298
# Actualizacion: b = c
# Error relativo aproximado: 20.0%
#
# Iteracion 4
# a es: 1.0, b es: 1.25, c es: 1.125
# f(a): -1.103638323514327, f(b): 0.5818918594194298, f(c): -0.3721507614500492
# Actualizacion: a = c
# Error relativo aproximado: 11.11111111111111%
#
# Iteracion 5
# a es: 1.125, b es: 1.25, c es: 1.1875
# f(a): -0.3721507614500492, f(b): 0.5818918594194298, f(c): 0.07359234328088471
# Actualizacion: b = c
# Error relativo aproximado: 5.263157894736842%
#
# Iteracion 6
# ...
